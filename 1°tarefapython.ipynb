# %%
#1- Escreva um programa que leia 3 notas de um aluno e a média das notas dos exercícios realizados por ele. Calcular a média de
# aproveitamento, usando a fórmula: MA = (N1 + N2*2 + N3*3 + ME)/7. A partir da média, informar o conceito de acordo com os itens
# abaixo: maior ou igual a 9 menor que 4

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
media = float(input("Digite a média dos exercícios: "))

ma = (nota1 + nota2*2 + nota3*3 + media)/7

if ma >= 9:
    conceito = "A"
elif ma >= 7.5:
    conceito = "B"
elif ma >= 6:
    conceito = "C"
elif ma >= 4:
    conceito = "D"
else:
    conceito = "E"

print("Média de aproveitamento: {:.2f}".format(ma))
print("Conceito:", conceito)

# %%
#2- Elabore um programa que solicita: nome, endereço, CEP e telefone. Imprima na tela os valores conforme abaixo:
# nome na primeira linha, endereço na segunda linha, CEP e telefone na terceira linha.

nome = str(input("Digite o seu nome:"))
endereco = input("Digite o seu endereço:")
cep = input("Digite o seu CEP: ")
telefone = int(input("Digite o seu telefone:"))

print("Nome:", nome)
print("Endereço:", endereco)
print("CEP e Telefone:", cep, telefone)

# %%
#3- Escreva um programa que imprima na tela a figura abaixo:

print("XXXXX")
print("X   X")
print("X   X")
print("X   X")
print("XXXXX")

# %%
#4- Escreva um programa que o usuário deva entrar com o nome do aluno e sua nota. Exiba o valor conforme abaixo:

nome_aluno = input("Digite o nome do aluno(a): ")
nota_aluno = float(input("Digite a nota do aluno(a): "))

print("\nALUNO(A)       NOTA")
print("=========      =====")
print("{:<12}   {:<6.1f}".format(nome_aluno, nota_aluno))

# %%
#5- Elabore um programa que mostre o seguinte menu na tela: Cadastro de Clientes
# - Fim
# - Inclui
# - Altera
# - Exclui
# - Consulta
#Quando o usuário entrar com uma opção exibir o item. Se entrar com um valor diferente do menu exibir item não encontrado.

print("Cadastro de Clientes")
print("0 - Fim")
print("1 - Inclui")
print("2 - Altera")
print("3 - Exclui")
print("4 - Consulta")

opcao = int(input("Escolha uma opção: "))

if opcao == 0:
    print("Fim do programa")
elif opcao == 1:
    print("Inclusão de cliente")
elif opcao == 2:
    print("Alteração de cliente")
elif opcao == 3:
    print("Exclusão de cliente")
elif opcao == 4:
    print("Consulta de cliente")
else:
    print("Opção inválida")

# %%
#6- Implemente um programa que desenhe um "pinheiro" na tela, similar ao abaixo. O valor de X deve ser fornecido pelo usuário

caracter = input("Enter a caracter: ")

espaco = " " * 6
folha = caracter * 1
print(espaco + folha)

espaco = " " * 5
folha = caracter * 3
print(espaco + folha)

espaco = " " * 4
folha = caracter * 5
print(espaco + folha)

espaco = " " * 3
folha = caracter * 7
print(espaco + folha)

espaco = " " * 2
folha = caracter * 9
print(espaco + folha)

espaco = " " * 1
folha = caracter * 11
print(espaco + folha)

folha = caracter * 13
print(folha)

espaco = " " * 5
folha = caracter * 2
print(espaco + folha)

espaco = " " * 5
folha = caracter * 2
print(espaco + folha)

espaco = " " * 4
folha = caracter * 4
print(espaco + folha)

# %%
#7- Sendo x uma variável do tipo int com valor 17 e y uma variável float com valor 3.2, calcule o valor das seguintes expressões em python:

x = 17
y = 3.2

result1 = x / 4 + y
print("a) x / 4 + y =", result1)

result2 = x * y ** 6
print("b) x * y ** 6 =", result2)

result1 = x % 4
result2 = int(y * 10) // 4
result = (result1, result2)
print("c) (x % 4) , (((int) y * 10) // 4) =", result)

result = (x / 6 // x / 3) + 4
print("d) (x / 6 // x / 3) + 4 =", result)
# Out:
# a) x / 4 + y = 7.45
# b) x * y ** 6 = 18253.611008000007
# c) (x % 4) , (((int) y * 10) // 4) = (1, 8)
# d) (x / 6 // x / 3) + 4 = 4.0

# %%
#8- Considere a fórmula S = n*(a1 + an)/2. É a soma de termos de uma PA. Faça um programa onde o usuário deva entrar com o número de termos (n),
# valor inicial (a1) e valor final (an). O resultado da soma deve ser mostrado na tela.

n = int(input("Digite o número de termos (n): "))
a1 = int(input("Digite o valor inicial (a1): "))
an = int(input("Digite o valor final (an): "))

S = n * (a1 + an) / 2

print("A soma dos termos da PA é:", S)

# %%
#9- Considere a fórmula Sn = a1*(q**n -1) / (q-1).
# Faça um programa onde o usuário deva entrar com o valor inicial (a1), a quantidade de termos (n) e a razão (q). Para nosso
# exercício a razão deve ser maior ou igual a 2.

a1 = int(input("Digite o valor inicial (a1): "))
n = int(input("Digite a quantidade de termos (n): "))
q = int(input("Digite a razão (q) [q >= 2]: "))

if q >= 2:
    Sn = a1 * (q**n - 1) / (q - 1)
    print("A soma dos termos da PA é:", Sn)
else:
    print("A razão (q) deve ser maior ou igual a 2.")

# %%
#10- Escreva um programa para ler o ano de nascimento de uma pessoa e escrever uma mensagem que diga se ela poderá ou não votar este
#ano (não é necessário considerar o mês em que ela nasceu).

from datetime import date

ano_atual = date.today().year
ano_nascimento = int(input("Digite o ano de nascimento: "))
idade = ano_atual - ano_nascimento

if idade >= 16:
    print("Você pode votar este ano. Sua idade é: ", idade)
else:
    print("Você não pode votar este ano. Sua idade é: ", idade)

# %%
#11- Escreva um programa que verifique a validade de uma senha fornecida pelo usuário. A senha válida é o número 8765. Devem ser impressas as
# seguintes mensagens: ACESSO PERMITIDO caso a senha seja válida. ACESSO NEGADO caso a senha seja inválida.

senha = int(input("Digite a senha: "))

if senha == 8765:
    print("ACESSO PERMITIDO")
else:
    print("ACESSO NEGADO")

# %%
#12- Tendo como entrada a altura e o sexo (codificado da seguinte forma:
# 1:feminino 2:masculino) de uma pessoa, construa um programa que calcule e imprima seu peso ideal, utilizando as seguintes Fórmulas:
# - para homens: (72.7 * Altura) – 58
# - para mulheres: (62.1 * Altura) – 44.7

altura = float(input("Digite sua altura: "))
sexo = int(input("Digite seu sexo (1 para feminino e 2 para masculino): "))

if sexo == 1:
    peso_ideal = 62.1 * altura - 44.7
    print("Seu peso ideal é: ", peso_ideal)

elif sexo == 2:
    peso_ideal = 72.7 * altura - 58
    print("Seu peso ideal é: ", peso_ideal)

else:
    print("Sexo inválido.")

# %%
#13- Escreva um programa para ler o número de lados de um polígono regular. Calcular e imprimir o seguinte:
# − Se o número de lados for igual a 3 escrever TRIÂNGULO e o valor da área
# − Se o número de lados for igual a 4 escrever QUADRADO e o valor da sua área.
# − Se o número de lados for igual a 5 escrever PENTÁGONO.

num_lados = int(input("Insira o número de lados do polígono: "))

if num_lados == 3:
    print("TRIÂNGULO")
    lado = float(input("Insira o comprimento do lado: "))
    area = (lado**2 * (3)**0.5) / 4
    print("A área é:", area)
elif num_lados == 4:
    print("QUADRADO")
    lado = float(input("Insira o comprimento do lado: "))
    area = lado**2
    print("A área é:", area)
elif num_lados == 5:
    print("PENTÁGONO")
else:
    print("Número de lados inválido.")

# %%
#14- Acrescente as seguintes mensagens à solução do exercício anterior conforme o caso.
# − Caso o número de lados seja inferior a 3 escrever NÃO É UM POLÍGONO.
# − Caso o número de lados seja superior a 5 escrever POLÍGONO NÃO IDENTIFICADO

lados = int(input("Informe o número de lados do polígono: "))

if lados < 3:
    print("NÃO É UM POLÍGONO")
elif lados == 3:
    print("TRIÂNGULO")
    area = (lados**2 * (3**0.5)) / 4
    print("A área do triângulo é de", area)
elif lados == 4:
    print("QUADRADO")
    area = lados**2
    print("A área do quadrado é de", area)
elif lados == 5:
    print("PENTÁGONO")
else:
    print("POLÍGONO NÃO IDENTIFICADO")
