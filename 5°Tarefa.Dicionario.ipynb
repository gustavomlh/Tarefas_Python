# %%
#1- Escreva uma função que receba itens (números) em um dicionário como entrada e retorne a chave com o maior valor.

id_aluno =  { 20 : 'gustavo', 2 : 'breno', 19 : 'lossi'}
lista = []
lista_nome = []

for idade, nome in id_aluno.items(): 
    lista.append(idade) 

print(max(lista))
# Out:
# 20

# %%
#2 Escreva uma função que receba Nome e Idade. Retorne valores que contêm a
# chave "idade" e cujo valor é maior que 18.
id_aluno =  { 1 : 'gustavo', 2 : 'breno', 19 : 'lossi'}

for idade, nome in id_aluno.items(): 
    if idade > 18:   
        print(idade,)
# Out:
# 19

# %%
#3 -Escreva uma função que receba duas listas de mesmo comprimento, uma contendo 
#chaves e outra contendo valores, e retorna um dicionário criado a partir dessas listas.

cadastro = {}

while True:
    nome = input("digite o nome completo: ")
    if nome == '': #se o nome estiver em branco 
        break
    
    idade = int(input("digite a idade para ser nossa chave: "))

# adciona os dados pedidos acima ao nosso dicionário 

    cadastro = {"nome": nome, "idade" : idade}

print(cadastro)
# Out:
# digite o nome completo: gustavo
# digite a idade para ser nossa chave: 12
# digite a cidade para ser nosso valor : tte
# digite o nome completo:
# {'nome': 'gustavo', 'idade': 12}

# %%
#4- Escreva uma função que receba um dicionário como entrada e retorna duas listas. 
#Uma com chave e outra com valor.
id_aluno =  { 1 : 'gustavo', 2 : 'breno', 19 : 'lossi'}
lista = []
lista_nome = []

for idade, nome in id_aluno.items(): 
    lista.append(idade) 
    lista_nome.append(nome)

print(lista, lista_nome)
# Out:
# [1, 2, 19] ['gustavo', 'breno', 'lossi']

# %%
#5- Escreva uma função que receba um dicionário como entrada e retorna uma nova 
#lista contendo apenas as chaves

id_aluno =  { 1 : 'gustavo', 2 : 'breno', 19 : 'lossi'}
lista = []
lista_nome = []

for idade, nome in id_aluno.items(): 
    lista.append(idade) 
    

print(lista)
# Out:
# [1, 2, 19]

# %%
#6- Escreva uma função que receba um dicionário como entrada e retorna uma nova 
#lista com as chaves ordenadas em ordem alfabética.

id_aluno =  { 1 : 'gustavo', 2 : 'breno', 19 : 'lossi0'}
lista = []
lista_nome = []

for idade, nome in id_aluno.items(): 
    lista_nome.append(nome) 


lista_nome.sort()    

print(lista_nome)
# Out:
# ['breno', 'gustavo', 'lossi']
